# %% [markdown]
# #EDA & Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data = pd.read_csv('energy_production.csv', delimiter = ';')

# %%
data
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0            9.59           38.56       1017.01       60.10             481.30
# 1           12.04           42.34       1019.72       94.67             465.36
# 2           13.87           45.08       1024.42       81.69             465.48
# 3           13.72           54.30       1017.89       79.08             467.05
# 4           15.14           49.64       1023.78       75.00             463.58
# ...           ...             ...           ...         ...                ...
# 9563        17.10           49.69       1005.53       81.82             457.32
# 9564        24.73           65.34       1015.42       52.80             446.92
# 9565        30.44           56.24       1005.19       56.24             429.34
# 9566        23.00           66.05       1020.61       80.29             421.57
# 9567        17.75           49.25       1020.86       63.67             454.41
#
# [9568 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   temperature        9568 non-null   float64
#  1   exhaust_vacuum     9568 non-null   float64
#  2   amb_pressure       9568 non-null   float64
#  3   r_humidity         9568 non-null   float64
#  4   energy_production  9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
data.shape
# Out:
# (9568, 5)

# %%
data.describe()
# Out:
#        temperature  exhaust_vacuum  amb_pressure   r_humidity  \
# count  9568.000000     9568.000000   9568.000000  9568.000000
# mean     19.651231       54.305804   1013.259078    73.308978
# std       7.452473       12.707893      5.938784    14.600269
# min       1.810000       25.360000    992.890000    25.560000
# 25%      13.510000       41.740000   1009.100000    63.327500
# 50%      20.345000       52.080000   1012.940000    74.975000
# 75%      25.720000       66.540000   1017.260000    84.830000
# max      37.110000       81.560000   1033.300000   100.160000
#
#        energy_production
# count        9568.000000
# mean          454.365009
# std            17.066995
# min           420.260000
# 25%           439.750000
# 50%           451.550000
# 75%           468.430000
# max           495.760000

# %%
data.isnull().sum() #No null values.
# Out:
# temperature          0
# exhaust_vacuum       0
# amb_pressure         0
# r_humidity           0
# energy_production    0
# dtype: int64

# %%
plt.figure(figsize=(10,8))
cor = data.corr()
sn.heatmap(cor, annot=True)

# %%
#Checking for outliers in the data.
columns = ['temperature','exhaust_vacuum','amb_pressure', 'r_humidity']
plt.figure(figsize=(15,10))
for i in range(0,4):
  plt.subplot(2,2,i+1)
  sn.boxplot(columns[i],data=data)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15,10))
for i in range(0,4):
  plt.subplot(2,2,i+1)
  sn.distplot(data[columns[i]])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Ploting the pair plot to see the relationship between the variables.
sn.pairplot(data)

# %%
#Ploting the regression plots between the independent and dependent variables.
sn.lmplot(x='temperature', y='energy_production', data=data)

# %%
sn.lmplot(x='exhaust_vacuum', y='energy_production', data=data)

# %%
sn.lmplot(x='amb_pressure', y='energy_production', data=data)

# %%
sn.lmplot(x='r_humidity', y='energy_production', data=data)

# %%
#Defining X & Y values
x = data.drop(['energy_production'], axis=1)
y = data['energy_production']

# %%
x
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity
# 0            9.59           38.56       1017.01       60.10
# 1           12.04           42.34       1019.72       94.67
# 2           13.87           45.08       1024.42       81.69
# 3           13.72           54.30       1017.89       79.08
# 4           15.14           49.64       1023.78       75.00
# ...           ...             ...           ...         ...
# 9563        17.10           49.69       1005.53       81.82
# 9564        24.73           65.34       1015.42       52.80
# 9565        30.44           56.24       1005.19       56.24
# 9566        23.00           66.05       1020.61       80.29
# 9567        17.75           49.25       1020.86       63.67
#
# [9568 rows x 4 columns]

# %%
y
# Out:
# 0       481.30
# 1       465.36
# 2       465.48
# 3       467.05
# 4       463.58
#          ...
# 9563    457.32
# 9564    446.92
# 9565    429.34
# 9566    421.57
# 9567    454.41
# Name: energy_production, Length: 9568, dtype: float64

# %%
#Normalizing the data
from sklearn import preprocessing
data_norm = preprocessing.normalize(x)
names = ['temperature', 'exhaust_vacuum', 'amb_pressure', 'r_humidity']
x_norm = pd.DataFrame(data_norm, columns=names)
x_norm
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity
# 0        0.009406        0.037820      0.997500    0.058947
# 1        0.011746        0.041305      0.994800    0.092356
# 2        0.013482        0.043820      0.995787    0.079407
# 3        0.013418        0.053106      0.995499    0.077340
# 4        0.014730        0.048296      0.996055    0.072969
# ...           ...             ...           ...         ...
# 9563     0.016927        0.049187      0.995356    0.080992
# 9564     0.024264        0.064110      0.996302    0.051806
# 9565     0.030175        0.055750      0.996430    0.055750
# 9566     0.022414        0.064367      0.994602    0.078244
# 9567     0.017331        0.048087      0.996756    0.062167
#
# [9568 rows x 4 columns]

# %%
# performing the train test split on the data
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_norm,y,test_size=0.20, random_state=24)

# %%
x_train.head()
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity
# 8477     0.025549        0.057375      0.995597    0.069585
# 8131     0.021648        0.046137      0.997186    0.054975
# 1542     0.011917        0.039663      0.995786    0.081825
# 385      0.013716        0.041399      0.996785    0.067218
# 9465     0.024234        0.068433      0.994123    0.080300

# %%
y_train.head()
# Out:
# 8477    443.74
# 8131    451.92
# 1542    464.03
# 385     468.63
# 9465    438.10
# Name: energy_production, dtype: float64

# %%
x_test.head()
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity
# 486      0.023240        0.068855      0.993984    0.081940
# 6542     0.031061        0.078779      0.994816    0.056303
# 2977     0.012374        0.040909      0.994961    0.090698
# 2448     0.023874        0.058630      0.996100    0.061461
# 6190     0.011656        0.042507      0.995246    0.086847

# %%
#Conacting the dataframes x_train and y_train
df_ols = pd.concat([x_train, y_train], axis=1)
df_ols
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 8477     0.025549        0.057375      0.995597    0.069585             443.74
# 8131     0.021648        0.046137      0.997186    0.054975             451.92
# 1542     0.011917        0.039663      0.995786    0.081825             464.03
# 385      0.013716        0.041399      0.996785    0.067218             468.63
# 9465     0.024234        0.068433      0.994123    0.080300             438.10
# ...           ...             ...           ...         ...                ...
# 6500     0.029746        0.067078      0.996070    0.049599             431.25
# 5249     0.025154        0.066910      0.995608    0.060459             437.49
# 3473     0.004092        0.039339      0.994661    0.095321             491.22
# 8535     0.027164        0.066395      0.995662    0.059255             442.13
# 899      0.027056        0.048846      0.997616    0.040539             443.78
#
# [7654 rows x 5 columns]

# %% [markdown]
# # MLR Model

# %%
import statsmodels.formula.api as smf
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
mlr = smf.ols('energy_production~temperature+exhaust_vacuum+amb_pressure+r_humidity', data = df_ols).fit()

# %%
mlr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      energy_production   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                 2.497e+04
# Date:                Wed, 29 Jun 2022   Prob (F-statistic):               0.00
# Time:                        16:15:46   Log-Likelihood:                -22464.
# No. Observations:                7654   AIC:                         4.494e+04
# Df Residuals:                    7649   BIC:                         4.497e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       4499.0465    362.128     12.424      0.000    3789.176    5208.917
# temperature    -2063.5909     16.523   -124.893      0.000   -2095.980   -2031.201
# exhaust_vacuum  -471.4143     22.151    -21.282      0.000    -514.835    -427.993
# amb_pressure   -3965.8585    360.750    -10.993      0.000   -4673.027   -3258.690
# r_humidity      -435.0441     25.097    -17.334      0.000    -484.241    -385.847
# ==============================================================================
# Omnibus:                      991.063   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5537.748
# Skew:                          -0.492   Prob(JB):                         0.00
# Kurtosis:                       7.049   Cond. No.                     1.39e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.39e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y_pred = mlr.predict(x_test)

# %%
y_pred
# Out:
# 486     440.980770
# 6542    428.017206
# 2977    468.895357
# 2448    445.010916
# 6190    470.166033
#            ...
# 2511    444.242740
# 7637    439.893650
# 7674    436.481927
# 3322    464.030817
# 3228    472.146613
# Length: 1914, dtype: float64

# %%
#testing the accuracy of the linear regression model
from sklearn.metrics import mean_squared_error , mean_absolute_error

# %%
y_pred_train = mlr.predict(x_train)
y_pred_train
# Out:
# 8477    440.607246
# 8131    454.007673
# 1542    471.014503
# 385     468.876304
# 9465    439.289822
#            ...
# 6500    434.191178
# 5249    440.853518
# 3473    485.906033
# 8535    437.258827
# 899     446.144976
# Length: 7654, dtype: float64

# %%
#Training Error
mean_squared_error(y_train,y_pred_train)
# Out:
# 20.737045759633293

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 19.127052054551214

# %%
#Training error
mean_absolute_error(y_train, y_pred_train)
# Out:
# 3.605233769572172

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 3.5772702090125454

# %%
rmse_mlr = np.sqrt(mean_squared_error(y_test,y_pred))
print(rmse_mlr)
# Out:
# 4.373448531142354

# %%
mlr_r_squared = mlr.rsquared
mlr_r_squared
# Out:
# 0.9288754976713905

# %% [markdown]
# # Lasso regression

# %%
from sklearn.linear_model import LassoCV
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
#defining cross-validation method to evaluate model
Lasso_cv = KFold(n_splits=10, random_state=24, shuffle=True)
Lasso_model_Kfold = LassoCV()

# %%
#useing LassoCV to evaluate model
Lasso_scores = cross_val_score(Lasso_model_Kfold, x, y, scoring='neg_mean_squared_error',
                         cv=Lasso_cv, n_jobs=-1)
Lasso_scores
# Out:
# array([-19.4860788 , -19.83701065, -22.89989849, -21.62819489,
#        -21.92514859, -20.73662307, -18.55734483, -21.93783409,
#        -19.95475547, -20.94932242])

# %%
Lasso_model_Kfold.fit(x, y)
# Out:
# LassoCV()

# %%
from numpy import mean
from numpy import absolute
from numpy import sqrt

# %%
#view RMSE
rmse_lasso = sqrt(mean(absolute(Lasso_scores)))
rmse_lasso
# Out:
# 4.559739151470063

# %%
#calculate R-squared of regression model
Lasso_r_squared = Lasso_model_Kfold.score(x, y)
Lasso_r_squared
# Out:
# 0.9286884621828044

# %% [markdown]
# #Ridge regression

# %%
from sklearn.linear_model import RidgeCV

# %%
#defining cross-validation method to evaluate model
Ridge_cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %%
#defining model
Ridge_model_Kfold = RidgeCV()

# %%
Ridge_model_Kfold.fit(x, y)
# Out:
# RidgeCV(alphas=array([ 0.1,  1. , 10. ]))

# %%
#Evaluating the model
Ridge_scores = cross_val_score(Ridge_model_Kfold, x, y, scoring='neg_mean_squared_error',
                         cv=Ridge_cv, n_jobs=-1)
Ridge_scores
# Out:
# array([-20.44154573, -21.58760054, -22.07902449, -20.93710648,
#        -21.83682326, -20.59124581, -19.96154202, -19.14852943,
#        -22.19823615, -19.19668657])

# %%
rmse_ridge = sqrt(mean(absolute(Ridge_scores)))
rmse_ridge
# Out:
# 4.560464236220477

# %%
#calculate R-squared of regression model
Ridge_r_squared = Ridge_model_Kfold.score(x, y)
Ridge_r_squared
# Out:
# 0.9286960883583321

# %% [markdown]
# # Elastic Net regression

# %%
from sklearn.linear_model import ElasticNetCV

# %%
#define cross-validation method to evaluate model
ElasticNet_cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %%
#define model
ElasticNet_model_Kfold = ElasticNetCV()

# %%
#use LOOCV to evaluate model
ElasticNet_scores = cross_val_score(ElasticNet_model_Kfold, x, y, scoring='neg_mean_squared_error',
                         cv=ElasticNet_cv, n_jobs=-1)
ElasticNet_scores
# Out:
# array([-20.49973023, -21.66507582, -22.09035395, -20.8980904 ,
#        -21.83792376, -20.72880992, -19.98613794, -19.16587853,
#        -22.16896538, -19.16387185])

# %%
#fit model
ElasticNet_model_Kfold.fit(x, y)
# Out:
# ElasticNetCV()

# %%
#view RMSE
rmse_elastic = sqrt(mean(absolute(ElasticNet_scores)))
rmse_elastic
# Out:
# 4.562946830399815

# %%
#calculate R-squared of regression model
ElasticNet_r_squared = ElasticNet_model_Kfold.score(x, y)
ElasticNet_r_squared
# Out:
# 0.9286193579081377

# %% [markdown]
# #Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor(criterion='squared_error', max_depth = 5)
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
from sklearn import tree
tree.plot_tree(dtr)
# Out:
# [Text(0.5, 0.9166666666666666, 'X[0] <= 0.017\nsquared_error = 291.56\nsamples = 7654\nvalue = 454.371'),
#  Text(0.25, 0.75, 'X[0] <= 0.011\nsquared_error = 87.716\nsamples = 3132\nvalue = 471.814'),
#  Text(0.125, 0.5833333333333334, 'X[0] <= 0.009\nsquared_error = 43.27\nsamples = 1387\nvalue = 479.597'),
#  Text(0.0625, 0.4166666666666667, 'X[0] <= 0.007\nsquared_error = 31.679\nsamples = 643\nvalue = 483.649'),
#  Text(0.03125, 0.25, 'X[0] <= 0.005\nsquared_error = 26.702\nsamples = 328\nvalue = 485.712'),
#  Text(0.015625, 0.08333333333333333, 'squared_error = 25.895\nsamples = 44\nvalue = 488.92'),
#  Text(0.046875, 0.08333333333333333, 'squared_error = 24.986\nsamples = 284\nvalue = 485.215'),
#  Text(0.09375, 0.25, 'X[2] <= 0.995\nsquared_error = 27.819\nsamples = 315\nvalue = 481.501'),
#  Text(0.078125, 0.08333333333333333, 'squared_error = 58.657\nsamples = 71\nvalue = 478.367'),
#  Text(0.109375, 0.08333333333333333, 'squared_error = 15.155\nsamples = 244\nvalue = 482.413'),
#  Text(0.1875, 0.4166666666666667, 'X[2] <= 0.995\nsquared_error = 26.832\nsamples = 744\nvalue = 476.095'),
#  Text(0.15625, 0.25, 'X[0] <= 0.009\nsquared_error = 19.716\nsamples = 155\nvalue = 472.375'),
#  Text(0.140625, 0.08333333333333333, 'squared_error = 12.794\nsamples = 24\nvalue = 475.822'),
#  Text(0.171875, 0.08333333333333333, 'squared_error = 18.408\nsamples = 131\nvalue = 471.743'),
#  Text(0.21875, 0.25, 'X[0] <= 0.01\nsquared_error = 24.105\nsamples = 589\nvalue = 477.074'),
#  Text(0.203125, 0.08333333333333333, 'squared_error = 21.576\nsamples = 405\nvalue = 477.978'),
#  Text(0.234375, 0.08333333333333333, 'squared_error = 23.909\nsamples = 184\nvalue = 475.083'),
#  Text(0.375, 0.5833333333333334, 'X[0] <= 0.014\nsquared_error = 36.633\nsamples = 1745\nvalue = 465.628'),
#  Text(0.3125, 0.4166666666666667, 'X[1] <= 0.041\nsquared_error = 22.441\nsamples = 837\nvalue = 469.173'),
#  Text(0.28125, 0.25, 'X[0] <= 0.013\nsquared_error = 20.372\nsamples = 405\nvalue = 470.701'),
#  Text(0.265625, 0.08333333333333333, 'squared_error = 16.959\nsamples = 297\nvalue = 471.674'),
#  Text(0.296875, 0.08333333333333333, 'squared_error = 20.008\nsamples = 108\nvalue = 468.028'),
#  Text(0.34375, 0.25, 'X[0] <= 0.013\nsquared_error = 20.139\nsamples = 432\nvalue = 467.741'),
#  Text(0.328125, 0.08333333333333333, 'squared_error = 22.767\nsamples = 180\nvalue = 469.152'),
#  Text(0.359375, 0.08333333333333333, 'squared_error = 15.823\nsamples = 252\nvalue = 466.732'),
#  Text(0.4375, 0.4166666666666667, 'X[1] <= 0.044\nsquared_error = 27.452\nsamples = 908\nvalue = 462.36'),
#  Text(0.40625, 0.25, 'X[0] <= 0.015\nsquared_error = 16.863\nsamples = 621\nvalue = 464.433'),
#  Text(0.390625, 0.08333333333333333, 'squared_error = 12.998\nsamples = 275\nvalue = 465.794'),
#  Text(0.421875, 0.08333333333333333, 'squared_error = 17.293\nsamples = 346\nvalue = 463.351'),
#  Text(0.46875, 0.25, 'X[1] <= 0.055\nsquared_error = 20.96\nsamples = 287\nvalue = 457.876'),
#  Text(0.453125, 0.08333333333333333, 'squared_error = 16.288\nsamples = 221\nvalue = 459.107'),
#  Text(0.484375, 0.08333333333333333, 'squared_error = 14.544\nsamples = 66\nvalue = 453.754'),
#  Text(0.75, 0.75, 'X[0] <= 0.022\nsquared_error = 76.037\nsamples = 4522\nvalue = 442.289'),
#  Text(0.625, 0.5833333333333334, 'X[1] <= 0.045\nsquared_error = 40.813\nsamples = 1395\nvalue = 451.179'),
#  Text(0.5625, 0.4166666666666667, 'X[0] <= 0.02\nsquared_error = 33.887\nsamples = 272\nvalue = 458.151'),
#  Text(0.53125, 0.25, 'X[3] <= 0.051\nsquared_error = 26.198\nsamples = 197\nvalue = 459.479'),
#  Text(0.515625, 0.08333333333333333, 'squared_error = 16.502\nsamples = 50\nvalue = 463.115'),
#  Text(0.546875, 0.08333333333333333, 'squared_error = 23.47\nsamples = 147\nvalue = 458.242'),
#  Text(0.59375, 0.25, 'X[2] <= 0.996\nsquared_error = 37.286\nsamples = 75\nvalue = 454.663'),
#  Text(0.578125, 0.08333333333333333, 'squared_error = 18.273\nsamples = 7\nvalue = 447.157'),
#  Text(0.609375, 0.08333333333333333, 'squared_error = 32.846\nsamples = 68\nvalue = 455.436'),
#  Text(0.6875, 0.4166666666666667, 'X[0] <= 0.02\nsquared_error = 27.864\nsamples = 1123\nvalue = 449.49'),
#  Text(0.65625, 0.25, 'X[2] <= 0.995\nsquared_error = 20.756\nsamples = 609\nvalue = 451.818'),
#  Text(0.640625, 0.08333333333333333, 'squared_error = 15.159\nsamples = 298\nvalue = 449.58'),
#  Text(0.671875, 0.08333333333333333, 'squared_error = 16.716\nsamples = 311\nvalue = 453.963'),
#  Text(0.71875, 0.25, 'X[2] <= 0.995\nsquared_error = 22.25\nsamples = 514\nvalue = 446.731'),
#  Text(0.703125, 0.08333333333333333, 'squared_error = 14.175\nsamples = 254\nvalue = 444.012'),
#  Text(0.734375, 0.08333333333333333, 'squared_error = 15.862\nsamples = 260\nvalue = 449.387'),
#  Text(0.875, 0.5833333333333334, 'X[1] <= 0.065\nsquared_error = 40.771\nsamples = 3127\nvalue = 438.323'),
#  Text(0.8125, 0.4166666666666667, 'X[0] <= 0.026\nsquared_error = 25.029\nsamples = 1283\nvalue = 443.249'),
#  Text(0.78125, 0.25, 'X[2] <= 0.996\nsquared_error = 22.759\nsamples = 904\nvalue = 444.584'),
#  Text(0.765625, 0.08333333333333333, 'squared_error = 15.029\nsamples = 369\nvalue = 442.552'),
#  Text(0.796875, 0.08333333333333333, 'squared_error = 23.279\nsamples = 535\nvalue = 445.986'),
#  Text(0.84375, 0.25, 'X[0] <= 0.028\nsquared_error = 16.056\nsamples = 379\nvalue = 440.066'),
#  Text(0.828125, 0.08333333333333333, 'squared_error = 14.825\nsamples = 264\nvalue = 440.839'),
#  Text(0.859375, 0.08333333333333333, 'squared_error = 14.358\nsamples = 115\nvalue = 438.29'),
#  Text(0.9375, 0.4166666666666667, 'X[0] <= 0.026\nsquared_error = 23.096\nsamples = 1844\nvalue = 434.896'),
#  Text(0.90625, 0.25, 'X[2] <= 0.994\nsquared_error = 18.487\nsamples = 522\nvalue = 438.153'),
#  Text(0.890625, 0.08333333333333333, 'squared_error = 12.478\nsamples = 280\nvalue = 436.872'),
#  Text(0.921875, 0.08333333333333333, 'squared_error = 21.344\nsamples = 242\nvalue = 439.635'),
#  Text(0.96875, 0.25, 'X[0] <= 0.03\nsquared_error = 19.075\nsamples = 1322\nvalue = 433.61'),
#  Text(0.953125, 0.08333333333333333, 'squared_error = 19.076\nsamples = 822\nvalue = 434.354'),
#  Text(0.984375, 0.08333333333333333, 'squared_error = 16.667\nsamples = 500\nvalue = 432.387')]

# %%
#Predicting testing data
y_pred = dtr.predict(x_test)

# %%
#predicting training data
y_pred_train=dtr.predict(x_train)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
#Training Errors
mean_squared_error(y_train, y_pred_train)
# Out:
# 18.509246109463614

# %%
#Testing Errors
mean_squared_error(y_test, y_pred)
# Out:
# 18.718145689394277

# %%
rmse_dtr = np.sqrt(mean_squared_error(y_test, y_pred))

# %%
rmse_dtr
# Out:
# 4.326447236404747

# %%
# r squared value on train data
dtr_r_squared = dtr.score(x_train,y_train)
dtr_r_squared
# Out:
# 0.9365164675203654

# %%
# r squared value on test data
dtr_r_squared = dtr.score(x_test,y_test)
dtr_r_squared
# Out:
# 0.9354590822656763

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# %%
reg = SVR()
param_grid = [
              {'kernel':['rbf'],
               'gamma':[0.5,0.1,0.01],
               'C':[10,0.1,0.001,0.0001] 
              }
             ]
gsv = GridSearchCV(reg,param_grid,cv=10)
gsv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=SVR(),
#              param_grid=[{'C': [10, 0.1, 0.001, 0.0001],
#                           'gamma': [0.5, 0.1, 0.01], 'kernel': ['rbf']}])

# %%
gsv.best_params_ , gsv.best_score_
# Out:
# ({'C': 10, 'gamma': 0.5, 'kernel': 'rbf'}, 0.7030065958664605)

# %%
reg = SVR(C= 10, gamma = 0.5)
reg.fit(x_train , y_train)
y_pred = reg.predict(x_test)

# %%
rmse_svm = np.sqrt(mean_squared_error(y_test, y_pred))

# %%
rmse_svm
# Out:
# 8.887133978758115

# %%
svm_r_squared = gsv.score(x_test,y_test)
svm_r_squared
# Out:
# 0.7276698230528929

# %% [markdown]
# #XGBoost

# %%
from xgboost.sklearn import XGBRegressor

# %%
xgb = XGBRegressor()
parameters = {'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], #so called `eta` value
              'max_depth': [5, 6, 7],
              'n_estimators': [300]}

# %%
xgb_grid = GridSearchCV(xgb,
                        parameters,
                        cv = 5,
                        verbose=True)

# %%
xgb_grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [16:23:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:23:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:24:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:24:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:24:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:24:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# GridSearchCV(cv=5, estimator=XGBRegressor(),
#              param_grid={'learning_rate': [0.03, 0.05, 0.07],
#                          'max_depth': [5, 6, 7], 'n_estimators': [300],
#                          'objective': ['reg:linear']},
#              verbose=True)

# %%
xgb_grid.best_params_ , gsv.best_score_
# Out:
# ({'learning_rate': 0.07,
#   'max_depth': 7,
#   'n_estimators': 300,
#   'objective': 'reg:linear'},
#  0.7030065958664605)

# %%
xgb = XGBRegressor(learning_rate=0.07,max_depth=7,objective='reg:linear', n_estimators=300)
xgb.fit(x_train , y_train)
y_pred = xgb.predict(x_test)
# Out:
# [16:24:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
rmse_xgb = sqrt(mean_squared_error(y_test,y_pred))

# %%
rmse_xgb
# Out:
# 3.450884702576804

# %%
#R squared on test data
xgb_r_squared = xgb.score(x_test,y_test)
xgb_r_squared
# Out:
# 0.9589386511214975

# %% [markdown]
# # Artificial Neural Network

# %%
#Defining the X & Y values
X = data.drop(['energy_production'], axis=1)
Y = data['energy_production']

# %%
#Standardizing the X variables.
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
std_x = scaler.fit_transform(x)

# %%
# performing the train test split on the data
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(std_x,Y,test_size=0.20, random_state=24)

# %%
#importing libraries
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor

# %%
from tensorflow.keras.optimizers import Adam

# %%
#Defining the model.
def model_reg():
  model = Sequential()
  model.add(Dense(8, input_dim=4, kernel_initializer='uniform', activation='relu'))
  model.add(Dense(4, input_dim=4, kernel_initializer='uniform', activation='relu'))
  model.add(Dense(1, kernel_initializer='uniform', activation='linear'))

  opti = Adam(learning_rate=0.001)
  model.compile(loss='mean_squared_error', optimizer=opti, metrics=['mse'])
  return model

# %%
model1 = KerasRegressor(build_fn=model_reg, verbose=0)
batch_size=[10,20,50,100]
epochs=[40,70,100]
param_grid=dict(batch_size=batch_size, epochs=epochs)
grid = GridSearchCV(estimator = model1, param_grid = param_grid, cv = KFold(), verbose=10)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   """Entry point for launching an IPython kernel.

# %%
grid_result = grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START batch_size=10, epochs=40...................................
# [CV 1/5; 1/12] END ..batch_size=10, epochs=40;, score=-22.432 total time=  42.3s
# [CV 2/5; 1/12] START batch_size=10, epochs=40...................................
# [CV 2/5; 1/12] END ..batch_size=10, epochs=40;, score=-22.907 total time=  27.3s
# [CV 3/5; 1/12] START batch_size=10, epochs=40...................................
# [CV 3/5; 1/12] END ..batch_size=10, epochs=40;, score=-18.585 total time=  41.7s
# [CV 4/5; 1/12] START batch_size=10, epochs=40...................................
# [CV 4/5; 1/12] END ..batch_size=10, epochs=40;, score=-21.337 total time=  28.3s
# [CV 5/5; 1/12] START batch_size=10, epochs=40...................................
# [CV 5/5; 1/12] END ..batch_size=10, epochs=40;, score=-21.943 total time=  41.7s
# [CV 1/5; 2/12] START batch_size=10, epochs=70...................................
# [CV 1/5; 2/12] END ..batch_size=10, epochs=70;, score=-21.559 total time= 1.4min
# [CV 2/5; 2/12] START batch_size=10, epochs=70...................................
# [CV 2/5; 2/12] END ..batch_size=10, epochs=70;, score=-23.995 total time=  50.5s
# [CV 3/5; 2/12] START batch_size=10, epochs=70...................................
# [CV 3/5; 2/12] END ..batch_size=10, epochs=70;, score=-22.105 total time=  48.1s
# [CV 4/5; 2/12] START batch_size=10, epochs=70...................................
# [CV 4/5; 2/12] END ..batch_size=10, epochs=70;, score=-20.538 total time=  47.2s
# [CV 5/5; 2/12] START batch_size=10, epochs=70...................................
# [CV 5/5; 2/12] END ..batch_size=10, epochs=70;, score=-21.494 total time= 1.4min
# [CV 1/5; 3/12] START batch_size=10, epochs=100..................................
# [CV 1/5; 3/12] END .batch_size=10, epochs=100;, score=-22.843 total time= 1.4min
# [CV 2/5; 3/12] START batch_size=10, epochs=100..................................
# [CV 2/5; 3/12] END .batch_size=10, epochs=100;, score=-22.504 total time= 1.1min
# [CV 3/5; 3/12] START batch_size=10, epochs=100..................................
# [CV 3/5; 3/12] END .batch_size=10, epochs=100;, score=-18.837 total time= 1.1min
# [CV 4/5; 3/12] START batch_size=10, epochs=100..................................
# [CV 4/5; 3/12] END .batch_size=10, epochs=100;, score=-21.796 total time= 1.1min
# [CV 5/5; 3/12] START batch_size=10, epochs=100..................................
# [CV 5/5; 3/12] END .batch_size=10, epochs=100;, score=-20.045 total time= 1.1min
# [CV 1/5; 4/12] START batch_size=20, epochs=40...................................
# [CV 1/5; 4/12] END ..batch_size=20, epochs=40;, score=-21.438 total time=  15.3s
# [CV 2/5; 4/12] START batch_size=20, epochs=40...................................
# [CV 2/5; 4/12] END ..batch_size=20, epochs=40;, score=-22.845 total time=  21.4s
# [CV 3/5; 4/12] START batch_size=20, epochs=40...................................
# [CV 3/5; 4/12] END ..batch_size=20, epochs=40;, score=-19.566 total time=  21.2s
# [CV 4/5; 4/12] START batch_size=20, epochs=40...................................
# [CV 4/5; 4/12] END ..batch_size=20, epochs=40;, score=-21.162 total time=  14.1s
# [CV 5/5; 4/12] START batch_size=20, epochs=40...................................
# [CV 5/5; 4/12] END ..batch_size=20, epochs=40;, score=-20.459 total time=  14.8s
# [CV 1/5; 5/12] START batch_size=20, epochs=70...................................
# [CV 1/5; 5/12] END ..batch_size=20, epochs=70;, score=-22.114 total time=  25.2s
# [CV 2/5; 5/12] START batch_size=20, epochs=70...................................
# [CV 2/5; 5/12] END ..batch_size=20, epochs=70;, score=-22.112 total time=  42.2s
# [CV 3/5; 5/12] START batch_size=20, epochs=70...................................
# [CV 3/5; 5/12] END ..batch_size=20, epochs=70;, score=-20.308 total time=  41.7s
# [CV 4/5; 5/12] START batch_size=20, epochs=70...................................
# [CV 4/5; 5/12] END ..batch_size=20, epochs=70;, score=-22.616 total time=  25.6s
# [CV 5/5; 5/12] START batch_size=20, epochs=70...................................
# [CV 5/5; 5/12] END ..batch_size=20, epochs=70;, score=-20.502 total time=  41.7s
# [CV 1/5; 6/12] START batch_size=20, epochs=100..................................
# [CV 1/5; 6/12] END .batch_size=20, epochs=100;, score=-21.488 total time=  41.6s
# [CV 2/5; 6/12] START batch_size=20, epochs=100..................................
# [CV 2/5; 6/12] END .batch_size=20, epochs=100;, score=-21.993 total time=  36.3s
# [CV 3/5; 6/12] START batch_size=20, epochs=100..................................
# [CV 3/5; 6/12] END .batch_size=20, epochs=100;, score=-18.562 total time=  35.7s
# [CV 4/5; 6/12] START batch_size=20, epochs=100..................................
# [CV 4/5; 6/12] END .batch_size=20, epochs=100;, score=-20.984 total time=  35.0s
# [CV 5/5; 6/12] START batch_size=20, epochs=100..................................
# [CV 5/5; 6/12] END .batch_size=20, epochs=100;, score=-21.085 total time=  41.7s
# [CV 1/5; 7/12] START batch_size=50, epochs=40...................................
# [CV 1/5; 7/12] END ..batch_size=50, epochs=40;, score=-48.008 total time=  10.9s
# [CV 2/5; 7/12] START batch_size=50, epochs=40...................................
# [CV 2/5; 7/12] END .batch_size=50, epochs=40;, score=-115.601 total time=  10.9s
# [CV 3/5; 7/12] START batch_size=50, epochs=40...................................
# [CV 3/5; 7/12] END .batch_size=50, epochs=40;, score=-253.124 total time=  10.9s
# [CV 4/5; 7/12] START batch_size=50, epochs=40...................................
# [CV 4/5; 7/12] END ..batch_size=50, epochs=40;, score=-88.585 total time=  10.9s
# [CV 5/5; 7/12] START batch_size=50, epochs=40...................................
# [CV 5/5; 7/12] END ..batch_size=50, epochs=40;, score=-38.177 total time=  10.9s
# [CV 1/5; 8/12] START batch_size=50, epochs=70...................................
# [CV 1/5; 8/12] END ..batch_size=50, epochs=70;, score=-22.084 total time=  10.8s
# [CV 2/5; 8/12] START batch_size=50, epochs=70...................................
# [CV 2/5; 8/12] END ..batch_size=50, epochs=70;, score=-23.356 total time=  10.6s
# [CV 3/5; 8/12] START batch_size=50, epochs=70...................................
# [CV 3/5; 8/12] END ..batch_size=50, epochs=70;, score=-19.634 total time=  10.9s
# [CV 4/5; 8/12] START batch_size=50, epochs=70...................................
# [CV 4/5; 8/12] END ..batch_size=50, epochs=70;, score=-21.517 total time=  10.9s
# [CV 5/5; 8/12] START batch_size=50, epochs=70...................................
# [CV 5/5; 8/12] END ..batch_size=50, epochs=70;, score=-24.266 total time=  11.4s
# [CV 1/5; 9/12] START batch_size=50, epochs=100..................................
# [CV 1/5; 9/12] END .batch_size=50, epochs=100;, score=-22.474 total time=  15.3s
# [CV 2/5; 9/12] START batch_size=50, epochs=100..................................
# [CV 2/5; 9/12] END .batch_size=50, epochs=100;, score=-22.241 total time=  21.1s
# [CV 3/5; 9/12] START batch_size=50, epochs=100..................................
# [CV 3/5; 9/12] END .batch_size=50, epochs=100;, score=-19.289 total time=  21.1s
# [CV 4/5; 9/12] START batch_size=50, epochs=100..................................
# [CV 4/5; 9/12] END .batch_size=50, epochs=100;, score=-20.410 total time=  21.1s
# [CV 5/5; 9/12] START batch_size=50, epochs=100..................................
# [CV 5/5; 9/12] END .batch_size=50, epochs=100;, score=-21.275 total time=  21.1s
# [CV 1/5; 10/12] START batch_size=100, epochs=40.................................
# [CV 1/5; 10/12] END batch_size=100, epochs=40;, score=-20732.416 total time=   3.6s
# [CV 2/5; 10/12] START batch_size=100, epochs=40.................................
# [CV 2/5; 10/12] END batch_size=100, epochs=40;, score=-11475.114 total time=   3.6s
# [CV 3/5; 10/12] START batch_size=100, epochs=40.................................
# [CV 3/5; 10/12] END batch_size=100, epochs=40;, score=-5293.042 total time=   5.7s
# [CV 4/5; 10/12] START batch_size=100, epochs=40.................................
# [CV 4/5; 10/12] END batch_size=100, epochs=40;, score=-3252.202 total time=   5.7s
# [CV 5/5; 10/12] START batch_size=100, epochs=40.................................
# [CV 5/5; 10/12] END batch_size=100, epochs=40;, score=-10967.171 total time=   3.6s
# [CV 1/5; 11/12] START batch_size=100, epochs=70.................................
# [CV 1/5; 11/12] END batch_size=100, epochs=70;, score=-202704.969 total time=   5.7s
# [CV 2/5; 11/12] START batch_size=100, epochs=70.................................
# [CV 2/5; 11/12] END batch_size=100, epochs=70;, score=-61.970 total time=   5.8s
# [CV 3/5; 11/12] START batch_size=100, epochs=70.................................
# [CV 3/5; 11/12] END batch_size=100, epochs=70;, score=-377.916 total time=  10.9s
# [CV 4/5; 11/12] START batch_size=100, epochs=70.................................
# [CV 4/5; 11/12] END batch_size=100, epochs=70;, score=-2029.161 total time=  10.9s
# [CV 5/5; 11/12] START batch_size=100, epochs=70.................................
# [CV 5/5; 11/12] END batch_size=100, epochs=70;, score=-202.482 total time=   5.9s
# [CV 1/5; 12/12] START batch_size=100, epochs=100................................
# [CV 1/5; 12/12] END batch_size=100, epochs=100;, score=-227.478 total time=   8.5s
# [CV 2/5; 12/12] START batch_size=100, epochs=100................................
# [CV 2/5; 12/12] END batch_size=100, epochs=100;, score=-201461.500 total time=   7.9s
# [CV 3/5; 12/12] START batch_size=100, epochs=100................................
# [CV 3/5; 12/12] END batch_size=100, epochs=100;, score=-20.012 total time=  10.9s
# [CV 4/5; 12/12] START batch_size=100, epochs=100................................
# [CV 4/5; 12/12] END batch_size=100, epochs=100;, score=-389.466 total time=   7.9s
# [CV 5/5; 12/12] START batch_size=100, epochs=100................................
# [CV 5/5; 12/12] END batch_size=100, epochs=100;, score=-200471.828 total time=   7.9s

# %%
# Summarizing the results
print('Best:{}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best:-20.822504806518555, using {'batch_size': 20, 'epochs': 100}
# -21.440711975097656,1.5198717648826625 with: {'batch_size': 10, 'epochs': 40}
# -21.9384822845459,1.1455002206425435 with: {'batch_size': 10, 'epochs': 70}
# -21.204796981811523,1.5279651149671654 with: {'batch_size': 10, 'epochs': 100}
# -21.093996429443358,1.0887595406684485 with: {'batch_size': 20, 'epochs': 40}
# -21.53046226501465,0.9392494869006651 with: {'batch_size': 20, 'epochs': 70}
# -20.822504806518555,1.184734357497699 with: {'batch_size': 20, 'epochs': 100}
# -108.69902267456055,77.41768465850149 with: {'batch_size': 50, 'epochs': 40}
# -22.17148208618164,1.5915791259458736 with: {'batch_size': 50, 'epochs': 70}
# -21.137621307373045,1.1806138807178346 with: {'batch_size': 50, 'epochs': 100}
# -10343.989013671875,6089.215446670825 with: {'batch_size': 100, 'epochs': 40}
# -41075.29967956543,80817.95381160222 with: {'batch_size': 100, 'epochs': 70}
# -80514.05692749024,98349.70957798143 with: {'batch_size': 100, 'epochs': 100}

# %% [markdown]
# ## Hyperparameter Tuning - learning Rate & Dropout Rate

# %%
from keras.layers import Dropout

# %%
def model_reg1(learning_rate,dropout_rate):
  model = Sequential()
  model.add(Dense(8, input_dim=4, kernel_initializer='uniform', activation='relu'))
  model.add(Dropout(dropout_rate))
  model.add(Dense(4,input_dim=4, kernel_initializer='uniform', activation='relu'))
  model.add(Dropout(dropout_rate))
  model.add(Dense(1, kernel_initializer='uniform', activation='linear'))

  opti = Adam(lr=learning_rate)
  model.compile(loss='mean_squared_error', optimizer=opti, metrics=['mse'] )
  return model

# %%
model2 = KerasRegressor(build_fn=model_reg1, verbose=0, batch_size=50, epochs=100)
learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]
param_grids = dict(learning_rate=learning_rate, dropout_rate=dropout_rate)
grid = GridSearchCV(estimator = model2,param_grid = param_grids,cv = KFold(),verbose = 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   """Entry point for launching an IPython kernel.

# %%
gird_result1 = grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=-21.443 total time=  15.0s
# [CV 2/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=-23.366 total time=  14.8s
# [CV 3/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=-18.803 total time=  21.2s
# [CV 4/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=-21.979 total time=  14.9s
# [CV 5/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=-21.267 total time=  21.2s
# [CV 1/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=-23.627 total time=  16.1s
# [CV 2/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=-28.020 total time=  15.4s
# [CV 3/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=-111939.367 total time=  21.2s
# [CV 4/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=-20.799 total time=  21.2s
# [CV 5/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=-23.073 total time=  15.0s
# [CV 1/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=-32.186 total time=  15.6s
# [CV 2/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=-45.639 total time=  21.2s
# [CV 3/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=-24.581 total time=  15.5s
# [CV 4/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=-24.214 total time=  15.5s
# [CV 5/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=-21.801 total time=  15.1s
# [CV 1/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=-464.620 total time=  15.6s
# [CV 2/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=-917.276 total time=  21.2s
# [CV 3/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=-920.324 total time=  21.2s
# [CV 4/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=-812.092 total time=  15.5s
# [CV 5/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=-445.782 total time=  15.3s
# [CV 1/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=-303.930 total time=  21.2s
# [CV 2/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=-449.777 total time=  16.0s
# [CV 3/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=-314.191 total time=  17.3s
# [CV 4/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=-453.263 total time=  21.3s
# [CV 5/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=-94.690 total time=  16.7s
# [CV 1/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=-40.940 total time=  21.3s
# [CV 2/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=-27.316 total time=  21.8s
# [CV 3/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=-21.118 total time=  16.6s
# [CV 4/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=-23.591 total time=  16.8s
# [CV 5/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=-24.614 total time=  16.6s
# [CV 1/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=-3926.011 total time=  21.2s
# [CV 2/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=-3293.774 total time=  21.2s
# [CV 3/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=-1734.449 total time=  21.3s
# [CV 4/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=-1455.627 total time=  21.3s
# [CV 5/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=-1278.818 total time=  16.2s
# [CV 1/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=-1779.430 total time=  16.2s
# [CV 2/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=-894.752 total time=  21.2s
# [CV 3/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=-4731.529 total time=  15.7s
# [CV 4/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=-1829.773 total time=  15.9s
# [CV 5/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=-1006.540 total time=  21.2s
# [CV 1/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=-293.517 total time=  15.6s
# [CV 2/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=-52.265 total time=  21.8s
# [CV 3/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=-47.919 total time=  21.2s
# [CV 4/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=-74.783 total time=  21.2s
# [CV 5/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=-294.124 total time=  21.3s

# %%
print('Best : {}, using {}'.format(gird_result1.best_score_,gird_result1.best_params_))
means = gird_result1.cv_results_['mean_test_score']
stds = gird_result1.cv_results_['std_test_score']
params = gird_result1.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : -21.371627807617188, using {'dropout_rate': 0.0, 'learning_rate': 0.001}
# -21.371627807617188,1.480544571637661 with: {'dropout_rate': 0.0, 'learning_rate': 0.001}
# -22406.977150726318,44766.19507947686 with: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# -29.68421325683594,8.705311942650667 with: {'dropout_rate': 0.0, 'learning_rate': 0.1}
# -712.0190002441407,213.36539125274416 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# -323.170068359375,130.84908215982523 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# -27.515653228759767,6.999997117855537 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# -2337.735986328125,1067.7082792905287 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# -2048.404577636719,1395.3996014867125 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# -152.52179718017578,115.73019851398568 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %% [markdown]
# ## Hyperparameter Tuning - Activation Function & Kernel Initializer

# %%
# Defining the function
def model_reg2(activation_function,init):
  model = Sequential()
  model.add(Dense(8, input_dim=4, kernel_initializer=init, activation=activation_function))
  model.add(Dropout(0.0))
  model.add(Dense(4, input_dim=4, kernel_initializer=init, activation=activation_function))
  model.add(Dropout(0.0))
  model.add(Dense(1,activation='linear'))

  opti = Adam(learning_rate=0.001)
  model.compile(loss='mean_squared_error', optimizer=opti, metrics=['mse'])
  return model

# %%
model3 = KerasRegressor(build_fn=model_reg2,verbose=0, batch_size=50, epochs=100)
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']
param_grids = dict(activation_function = activation_function,init = init)
grid = GridSearchCV(estimator = model3,param_grid = param_grids,cv = KFold(),verbose = 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   """Entry point for launching an IPython kernel.

# %%
grid_result2 = grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 1/5; 1/12] END activation_function=softmax, init=uniform;, score=-183704.062 total time=  15.8s
# [CV 2/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 2/5; 1/12] END activation_function=softmax, init=uniform;, score=-184166.766 total time=  21.2s
# [CV 3/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 3/5; 1/12] END activation_function=softmax, init=uniform;, score=-184150.328 total time=  21.3s
# [CV 4/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 4/5; 1/12] END activation_function=softmax, init=uniform;, score=-184110.172 total time=  16.5s
# [CV 5/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 5/5; 1/12] END activation_function=softmax, init=uniform;, score=-182991.125 total time=  15.7s
# [CV 1/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 1/5; 2/12] END activation_function=softmax, init=normal;, score=-184449.094 total time=  21.2s
# [CV 2/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 2/5; 2/12] END activation_function=softmax, init=normal;, score=-184474.672 total time=  15.6s
# [CV 3/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 3/5; 2/12] END activation_function=softmax, init=normal;, score=-184468.656 total time=  16.1s
# [CV 4/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 4/5; 2/12] END activation_function=softmax, init=normal;, score=-184397.797 total time=  15.3s
# [CV 5/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 5/5; 2/12] END activation_function=softmax, init=normal;, score=-183123.047 total time=  21.1s
# [CV 1/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 1/5; 3/12] END activation_function=softmax, init=zero;, score=-184206.859 total time=  21.2s
# [CV 2/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 2/5; 3/12] END activation_function=softmax, init=zero;, score=-184232.844 total time=  21.7s
# [CV 3/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 3/5; 3/12] END activation_function=softmax, init=zero;, score=-184330.016 total time=  16.2s
# [CV 4/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 4/5; 3/12] END activation_function=softmax, init=zero;, score=-183964.844 total time=  21.1s
# [CV 5/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 5/5; 3/12] END activation_function=softmax, init=zero;, score=-183197.422 total time=  16.2s
# [CV 1/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 1/5; 4/12] END activation_function=relu, init=uniform;, score=-21.693 total time=  16.3s
# [CV 2/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 2/5; 4/12] END activation_function=relu, init=uniform;, score=-21.827 total time=  15.7s
# [CV 3/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 3/5; 4/12] END activation_function=relu, init=uniform;, score=-19.872 total time=  15.2s
# [CV 4/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 4/5; 4/12] END activation_function=relu, init=uniform;, score=-21.746 total time=  15.6s
# [CV 5/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 5/5; 4/12] END activation_function=relu, init=uniform;, score=-20.992 total time=  15.6s
# [CV 1/5; 5/12] START activation_function=relu, init=normal......................
# [CV 1/5; 5/12] END activation_function=relu, init=normal;, score=-21.712 total time=  21.2s
# [CV 2/5; 5/12] START activation_function=relu, init=normal......................
# [CV 2/5; 5/12] END activation_function=relu, init=normal;, score=-21.930 total time=  15.4s
# [CV 3/5; 5/12] START activation_function=relu, init=normal......................
# [CV 3/5; 5/12] END activation_function=relu, init=normal;, score=-19.006 total time=  21.2s
# [CV 4/5; 5/12] START activation_function=relu, init=normal......................
# [CV 4/5; 5/12] END activation_function=relu, init=normal;, score=-21.456 total time=  15.5s
# [CV 5/5; 5/12] START activation_function=relu, init=normal......................
# [CV 5/5; 5/12] END activation_function=relu, init=normal;, score=-21.134 total time=  15.7s
# [CV 1/5; 6/12] START activation_function=relu, init=zero........................
# [CV 1/5; 6/12] END activation_function=relu, init=zero;, score=-195621.375 total time=  15.9s
# [CV 2/5; 6/12] START activation_function=relu, init=zero........................
# [CV 2/5; 6/12] END activation_function=relu, init=zero;, score=-196038.812 total time=  15.3s
# [CV 3/5; 6/12] START activation_function=relu, init=zero........................
# [CV 3/5; 6/12] END activation_function=relu, init=zero;, score=-195845.406 total time=  15.8s
# [CV 4/5; 6/12] START activation_function=relu, init=zero........................
# [CV 4/5; 6/12] END activation_function=relu, init=zero;, score=-196126.578 total time=  15.6s
# [CV 5/5; 6/12] START activation_function=relu, init=zero........................
# [CV 5/5; 6/12] END activation_function=relu, init=zero;, score=-195062.594 total time=  21.2s
# [CV 1/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 1/5; 7/12] END activation_function=tanh, init=uniform;, score=-152916.781 total time=  15.5s
# [CV 2/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 2/5; 7/12] END activation_function=tanh, init=uniform;, score=-152111.844 total time=  17.4s
# [CV 3/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 3/5; 7/12] END activation_function=tanh, init=uniform;, score=-152682.516 total time=  14.9s
# [CV 4/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 4/5; 7/12] END activation_function=tanh, init=uniform;, score=-152619.062 total time=  15.2s
# [CV 5/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 5/5; 7/12] END activation_function=tanh, init=uniform;, score=-151708.922 total time=  15.6s
# [CV 1/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 1/5; 8/12] END activation_function=tanh, init=normal;, score=-152145.531 total time=  21.2s
# [CV 2/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 2/5; 8/12] END activation_function=tanh, init=normal;, score=-152306.344 total time=  15.4s
# [CV 3/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 3/5; 8/12] END activation_function=tanh, init=normal;, score=-151948.656 total time=  21.1s
# [CV 4/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 4/5; 8/12] END activation_function=tanh, init=normal;, score=-153016.359 total time=  15.3s
# [CV 5/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 5/5; 8/12] END activation_function=tanh, init=normal;, score=-151073.484 total time=  16.1s
# [CV 1/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 1/5; 9/12] END activation_function=tanh, init=zero;, score=-149848.094 total time=  21.1s
# [CV 2/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 2/5; 9/12] END activation_function=tanh, init=zero;, score=-151507.078 total time=  21.1s
# [CV 3/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 3/5; 9/12] END activation_function=tanh, init=zero;, score=-150427.188 total time=  15.3s
# [CV 4/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 4/5; 9/12] END activation_function=tanh, init=zero;, score=-150895.047 total time=  15.2s
# [CV 5/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 5/5; 9/12] END activation_function=tanh, init=zero;, score=-149444.812 total time=  15.9s
# [CV 1/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 1/5; 10/12] END activation_function=linear, init=uniform;, score=-22.226 total time=  15.2s
# [CV 2/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 2/5; 10/12] END activation_function=linear, init=uniform;, score=-22.573 total time=  15.7s
# [CV 3/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 3/5; 10/12] END activation_function=linear, init=uniform;, score=-19.394 total time=  15.4s
# [CV 4/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 4/5; 10/12] END activation_function=linear, init=uniform;, score=-21.223 total time=  15.2s
# [CV 5/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 5/5; 10/12] END activation_function=linear, init=uniform;, score=-21.390 total time=  16.0s
# [CV 1/5; 11/12] START activation_function=linear, init=normal...................
# [CV 1/5; 11/12] END activation_function=linear, init=normal;, score=-22.279 total time=  21.2s
# [CV 2/5; 11/12] START activation_function=linear, init=normal...................
# [CV 2/5; 11/12] END activation_function=linear, init=normal;, score=-22.457 total time=  21.2s
# [CV 3/5; 11/12] START activation_function=linear, init=normal...................
# [CV 3/5; 11/12] END activation_function=linear, init=normal;, score=-19.549 total time=  15.3s
# [CV 4/5; 11/12] START activation_function=linear, init=normal...................
# [CV 4/5; 11/12] END activation_function=linear, init=normal;, score=-21.187 total time=  15.9s
# [CV 5/5; 11/12] START activation_function=linear, init=normal...................
# [CV 5/5; 11/12] END activation_function=linear, init=normal;, score=-23.616 total time=  21.2s
# [CV 1/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 1/5; 12/12] END activation_function=linear, init=zero;, score=-293.477 total time=  21.2s
# [CV 2/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 2/5; 12/12] END activation_function=linear, init=zero;, score=-298.540 total time=  21.2s
# [CV 3/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 3/5; 12/12] END activation_function=linear, init=zero;, score=-287.094 total time=  15.3s
# [CV 4/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 4/5; 12/12] END activation_function=linear, init=zero;, score=-285.142 total time=  15.6s
# [CV 5/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 5/5; 12/12] END activation_function=linear, init=zero;, score=-294.183 total time=  21.2s

# %%
print('Best : {}, using {}'.format(grid_result2.best_score_,grid_result2.best_params_))
means = grid_result2.cv_results_['mean_test_score']
stds = grid_result2.cv_results_['std_test_score']
params = grid_result2.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : -21.047553634643556, using {'activation_function': 'relu', 'init': 'normal'}
# -183824.490625,450.3192704860561 with: {'activation_function': 'softmax', 'init': 'uniform'}
# -184182.653125,530.4932766237182 with: {'activation_function': 'softmax', 'init': 'normal'}
# -183986.396875,412.39779564816877 with: {'activation_function': 'softmax', 'init': 'zero'}
# -21.22625732421875,0.7400731225847716 with: {'activation_function': 'relu', 'init': 'uniform'}
# -21.047553634643556,1.0546917494248398 with: {'activation_function': 'relu', 'init': 'normal'}
# -195738.953125,380.2072258260126 with: {'activation_function': 'relu', 'init': 'zero'}
# -152407.825,437.07737616342746 with: {'activation_function': 'tanh', 'init': 'uniform'}
# -152098.075,626.2565086207437 with: {'activation_function': 'tanh', 'init': 'normal'}
# -150424.44375,732.8613412961597 with: {'activation_function': 'tanh', 'init': 'zero'}
# -21.36117477416992,1.1052364914368942 with: {'activation_function': 'linear', 'init': 'uniform'}
# -21.81756477355957,1.3712790158795938 with: {'activation_function': 'linear', 'init': 'normal'}
# -291.6871826171875,4.905624617237167 with: {'activation_function': 'linear', 'init': 'zero'}

# %% [markdown]
# ## Hyperparameter Tuning - No. of Neurons in activation layer.

# %%
# Defining the model
def model_reg3(neuron1,neuron2):
  model = Sequential()
  model.add(Dense(neuron1, input_dim=4, kernel_initializer='normal', activation='relu'))
  model.add(Dropout(0.0))
  model.add(Dense(neuron2, input_dim=4, kernel_initializer='normal', activation='relu'))
  model.add(Dropout(0.0))
  model.add(Dense(1,activation='linear'))

  opti = Adam(learning_rate=0.001)
  model.compile(loss='mean_squared_error', optimizer=opti, metrics=['mse'])
  return model

# %%
model4 = KerasRegressor(build_fn=model_reg3,verbose=0, batch_size=50, epochs=100)
neuron1 = [4,8,16]
neuron2 = [2,4,8]
param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)
grid = GridSearchCV(estimator = model4,param_grid = param_grids,cv = KFold(),verbose = 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   """Entry point for launching an IPython kernel.

# %%
grid_results3 = grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 1/5; 1/9] END .......neuron1=4, neuron2=2;, score=-22.283 total time=  21.2s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 2/5; 1/9] END .......neuron1=4, neuron2=2;, score=-22.103 total time=  15.9s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 3/5; 1/9] END .......neuron1=4, neuron2=2;, score=-19.367 total time=  15.3s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 4/5; 1/9] END .......neuron1=4, neuron2=2;, score=-20.972 total time=  15.4s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 5/5; 1/9] END .......neuron1=4, neuron2=2;, score=-20.990 total time=  21.1s
# [CV 1/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 1/5; 2/9] END .......neuron1=4, neuron2=4;, score=-22.295 total time=  21.2s
# [CV 2/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 2/5; 2/9] END .......neuron1=4, neuron2=4;, score=-22.418 total time=  15.4s
# [CV 3/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 3/5; 2/9] END .......neuron1=4, neuron2=4;, score=-18.950 total time=  15.2s
# [CV 4/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 4/5; 2/9] END .......neuron1=4, neuron2=4;, score=-21.570 total time=  21.2s
# [CV 5/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 5/5; 2/9] END .......neuron1=4, neuron2=4;, score=-20.574 total time=  15.4s
# [CV 1/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 1/5; 3/9] END .......neuron1=4, neuron2=8;, score=-21.719 total time=  21.2s
# [CV 2/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 2/5; 3/9] END .......neuron1=4, neuron2=8;, score=-23.222 total time=  21.1s
# [CV 3/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 3/5; 3/9] END .......neuron1=4, neuron2=8;, score=-18.952 total time=  21.1s
# [CV 4/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 4/5; 3/9] END .......neuron1=4, neuron2=8;, score=-21.076 total time=  21.2s
# [CV 5/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 5/5; 3/9] END .......neuron1=4, neuron2=8;, score=-20.771 total time=  15.3s
# [CV 1/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 1/5; 4/9] END .......neuron1=8, neuron2=2;, score=-22.368 total time=  21.2s
# [CV 2/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 2/5; 4/9] END .......neuron1=8, neuron2=2;, score=-21.798 total time=  21.2s
# [CV 3/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 3/5; 4/9] END .......neuron1=8, neuron2=2;, score=-18.547 total time=  21.7s
# [CV 4/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 4/5; 4/9] END .......neuron1=8, neuron2=2;, score=-20.311 total time=  21.2s
# [CV 5/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 5/5; 4/9] END .......neuron1=8, neuron2=2;, score=-20.852 total time=  15.6s
# [CV 1/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 1/5; 5/9] END ...neuron1=8, neuron2=4;, score=-195621.391 total time=  15.5s
# [CV 2/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 2/5; 5/9] END .......neuron1=8, neuron2=4;, score=-21.928 total time=  21.2s
# [CV 3/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 3/5; 5/9] END .......neuron1=8, neuron2=4;, score=-19.323 total time=  15.2s
# [CV 4/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 4/5; 5/9] END .......neuron1=8, neuron2=4;, score=-21.132 total time=  15.2s
# [CV 5/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 5/5; 5/9] END .......neuron1=8, neuron2=4;, score=-20.326 total time=  15.8s
# [CV 1/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 1/5; 6/9] END .......neuron1=8, neuron2=8;, score=-22.574 total time=  15.7s
# [CV 2/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 2/5; 6/9] END .......neuron1=8, neuron2=8;, score=-22.639 total time=  15.2s
# [CV 3/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 3/5; 6/9] END .......neuron1=8, neuron2=8;, score=-18.704 total time=  21.2s
# [CV 4/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 4/5; 6/9] END .......neuron1=8, neuron2=8;, score=-21.344 total time=  15.4s
# [CV 5/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 5/5; 6/9] END .......neuron1=8, neuron2=8;, score=-21.078 total time=  21.2s
# [CV 1/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 1/5; 7/9] END ......neuron1=16, neuron2=2;, score=-22.236 total time=  15.9s
# [CV 2/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 2/5; 7/9] END ......neuron1=16, neuron2=2;, score=-22.419 total time=  15.6s
# [CV 3/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 3/5; 7/9] END ......neuron1=16, neuron2=2;, score=-19.438 total time=  21.2s
# [CV 4/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 4/5; 7/9] END ......neuron1=16, neuron2=2;, score=-21.074 total time=  21.2s
# [CV 5/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 5/5; 7/9] END ......neuron1=16, neuron2=2;, score=-20.176 total time=  16.4s
# [CV 1/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 1/5; 8/9] END ......neuron1=16, neuron2=4;, score=-23.624 total time=  15.2s
# [CV 2/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 2/5; 8/9] END ......neuron1=16, neuron2=4;, score=-21.278 total time=  21.2s
# [CV 3/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 3/5; 8/9] END ......neuron1=16, neuron2=4;, score=-18.315 total time=  21.2s
# [CV 4/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 4/5; 8/9] END ......neuron1=16, neuron2=4;, score=-20.635 total time=  21.2s
# [CV 5/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 5/5; 8/9] END ......neuron1=16, neuron2=4;, score=-19.440 total time=  21.2s
# [CV 1/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 1/5; 9/9] END ......neuron1=16, neuron2=8;, score=-20.419 total time=  21.2s
# [CV 2/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 2/5; 9/9] END ......neuron1=16, neuron2=8;, score=-21.675 total time=  16.2s
# [CV 3/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 3/5; 9/9] END ......neuron1=16, neuron2=8;, score=-18.406 total time=  21.2s
# [CV 4/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 4/5; 9/9] END ......neuron1=16, neuron2=8;, score=-20.231 total time=  21.5s
# [CV 5/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 5/5; 9/9] END ......neuron1=16, neuron2=8;, score=-19.691 total time=  21.2s

# %%
print('Best : {}, using {}'.format(grid_results3.best_score_,grid_results3.best_params_))
means = grid_results3.cv_results_['mean_test_score']
stds = grid_results3.cv_results_['std_test_score']
params = grid_results3.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : -20.084232330322266, using {'neuron1': 16, 'neuron2': 8}
# -21.14300537109375,1.0418837404135604 with: {'neuron1': 4, 'neuron2': 2}
# -21.161138916015624,1.2857320185336707 with: {'neuron1': 4, 'neuron2': 4}
# -21.14799346923828,1.3854897006973457 with: {'neuron1': 4, 'neuron2': 8}
# -20.775255584716795,1.3244161899928473 with: {'neuron1': 8, 'neuron2': 2}
# -39140.8201587677,78240.28523788146 with: {'neuron1': 8, 'neuron2': 4}
# -21.267823028564454,1.4283808331647645 with: {'neuron1': 8, 'neuron2': 8}
# -21.06853332519531,1.1526056066074755 with: {'neuron1': 16, 'neuron2': 2}
# -20.658381271362305,1.7975908869655979 with: {'neuron1': 16, 'neuron2': 4}
# -20.084232330322266,1.0616467660708087 with: {'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# ## Training Model with optimum values of Hyperparameters

# %%
# Defining the final model
final_model = Sequential()
final_model.add(Dense(16, input_dim=4, kernel_initializer='normal', activation='relu'))
final_model.add(Dropout(0.0))
final_model.add(Dense(8, input_dim=4, kernel_initializer='normal', activation='relu'))
final_model.add(Dropout(0.0))
final_model.add(Dense(1,activation='linear'))
opti = Adam(learning_rate=0.001)
final_model.compile(loss='mean_squared_error', optimizer=opti, metrics=['mse'])

# %%
final_model.fit(X_train,Y_train, batch_size=20, epochs=70)
# Out:
# Epoch 1/70
# 383/383 [==============================] - 1s 2ms/step - loss: 202375.8906 - mse: 202375.8906
# Epoch 2/70
# 383/383 [==============================] - 1s 2ms/step - loss: 146384.2188 - mse: 146384.2188
# Epoch 3/70
# 383/383 [==============================] - 1s 2ms/step - loss: 53878.2617 - mse: 53878.2617
# Epoch 4/70
# 383/383 [==============================] - 1s 2ms/step - loss: 21415.4980 - mse: 21415.4980
# Epoch 5/70
# 383/383 [==============================] - 1s 2ms/step - loss: 14257.1182 - mse: 14257.1182
# Epoch 6/70
# 383/383 [==============================] - 1s 2ms/step - loss: 8925.0107 - mse: 8925.0107
# Epoch 7/70
# 383/383 [==============================] - 1s 2ms/step - loss: 4591.4517 - mse: 4591.4517
# Epoch 8/70
# 383/383 [==============================] - 1s 2ms/step - loss: 1969.9982 - mse: 1969.9982
# Epoch 9/70
# 383/383 [==============================] - 1s 2ms/step - loss: 825.9589 - mse: 825.9589
# Epoch 10/70
# 383/383 [==============================] - 1s 2ms/step - loss: 360.0448 - mse: 360.0448
# Epoch 11/70
# 383/383 [==============================] - 1s 2ms/step - loss: 186.2944 - mse: 186.2944
# Epoch 12/70
# 383/383 [==============================] - 1s 2ms/step - loss: 101.0946 - mse: 101.0946
# Epoch 13/70
# 383/383 [==============================] - 1s 2ms/step - loss: 57.2586 - mse: 57.2586
# Epoch 14/70
# 383/383 [==============================] - 1s 2ms/step - loss: 37.1949 - mse: 37.1949
# Epoch 15/70
# 383/383 [==============================] - 1s 2ms/step - loss: 28.5979 - mse: 28.5979
# Epoch 16/70
# 383/383 [==============================] - 1s 2ms/step - loss: 24.8704 - mse: 24.8704
# Epoch 17/70
# 383/383 [==============================] - 1s 2ms/step - loss: 23.1268 - mse: 23.1268
# Epoch 18/70
# 383/383 [==============================] - 1s 2ms/step - loss: 22.2767 - mse: 22.2767
# Epoch 19/70
# 383/383 [==============================] - 1s 1ms/step - loss: 21.7437 - mse: 21.7437
# Epoch 20/70
# 383/383 [==============================] - 1s 2ms/step - loss: 21.3730 - mse: 21.3730
# Epoch 21/70
# 383/383 [==============================] - 1s 2ms/step - loss: 21.1992 - mse: 21.1992
# Epoch 22/70
# 383/383 [==============================] - 1s 2ms/step - loss: 21.1217 - mse: 21.1217
# Epoch 23/70
# 383/383 [==============================] - 1s 2ms/step - loss: 21.0082 - mse: 21.0082
# Epoch 24/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.9370 - mse: 20.9370
# Epoch 25/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.9133 - mse: 20.9133
# Epoch 26/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.8884 - mse: 20.8884
# Epoch 27/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.7000 - mse: 20.7000
# Epoch 28/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.8296 - mse: 20.8296
# Epoch 29/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.7194 - mse: 20.7194
# Epoch 30/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.6463 - mse: 20.6463
# Epoch 31/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.7119 - mse: 20.7119
# Epoch 32/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.5120 - mse: 20.5120
# Epoch 33/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.5295 - mse: 20.5295
# Epoch 34/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.3863 - mse: 20.3863
# Epoch 35/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.3084 - mse: 20.3084
# Epoch 36/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.4030 - mse: 20.4030
# Epoch 37/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.1307 - mse: 20.1307
# Epoch 38/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.1827 - mse: 20.1827
# Epoch 39/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.1029 - mse: 20.1029
# Epoch 40/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.1134 - mse: 20.1134
# Epoch 41/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.9820 - mse: 19.9820
# Epoch 42/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.0600 - mse: 20.0600
# Epoch 43/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.9537 - mse: 19.9537
# Epoch 44/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.0845 - mse: 20.0845
# Epoch 45/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.9803 - mse: 19.9803
# Epoch 46/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.0152 - mse: 20.0152
# Epoch 47/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.0668 - mse: 20.0668
# Epoch 48/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.0943 - mse: 20.0943
# Epoch 49/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.9917 - mse: 19.9917
# Epoch 50/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.8748 - mse: 19.8748
# Epoch 51/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.9857 - mse: 19.9857
# Epoch 52/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.9096 - mse: 19.9096
# Epoch 53/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.9925 - mse: 19.9925
# Epoch 54/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.8460 - mse: 19.8460
# Epoch 55/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.0053 - mse: 20.0053
# Epoch 56/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.8409 - mse: 19.8409
# Epoch 57/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.9954 - mse: 19.9954
# Epoch 58/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.8609 - mse: 19.8609
# Epoch 59/70
# 383/383 [==============================] - 1s 1ms/step - loss: 20.0163 - mse: 20.0163
# Epoch 60/70
# 383/383 [==============================] - 1s 1ms/step - loss: 19.8340 - mse: 19.8340
# Epoch 61/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.0659 - mse: 20.0659
# Epoch 62/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.8435 - mse: 19.8435
# Epoch 63/70
# 383/383 [==============================] - 1s 2ms/step - loss: 20.0939 - mse: 20.0939
# Epoch 64/70
# 383/383 [==============================] - 1s 1ms/step - loss: 19.8997 - mse: 19.8997
# Epoch 65/70
# 383/383 [==============================] - 1s 1ms/step - loss: 19.8818 - mse: 19.8818
# Epoch 66/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.9236 - mse: 19.9236
# Epoch 67/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.8985 - mse: 19.8985
# Epoch 68/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.8653 - mse: 19.8653
# Epoch 69/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.8776 - mse: 19.8776
# Epoch 70/70
# 383/383 [==============================] - 1s 2ms/step - loss: 19.7681 - mse: 19.7681

# %%
#Predicting the x_test data with the final model.

y_pred = final_model.predict(X_test)

# %%
y_pred_train = final_model.predict(X_train)

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Training Error

# %%
rmse_train_ann = np.sqrt(mean_squared_error(Y_train,y_pred_train))
rmse_train_ann
# Out:
# 4.441834929295236

# %% [markdown]
# Testing Error

# %%
rmse_ann = sqrt(mean_squared_error(Y_test,y_pred))

# %%
rmse_ann
# Out:
# 4.222718340717069

# %%
ann_r_squared = r2_score(Y_test, y_pred)
ann_r_squared
# Out:
# 0.9385167887631143

# %% [markdown]
# # Random Forest

# %%
#Using the train-test-split data (Done in EDA) & building a Random Forest Regressor model.
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(criterion='squared_error', max_depth = 5, random_state=24)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=5, random_state=24)

# %%
y_pred=rf.predict(x_test)

# %%
y_pred_train = rf.predict(x_train)

# %%
#Testing the erros of the model.
from sklearn.metrics import mean_squared_error, r2_score

# %%
#Testing Error
rmse_rf =  np.sqrt(mean_squared_error(y_test,y_pred))
rmse_rf
# Out:
# 4.097734671953504

# %%
#Training Error
mean_squared_error(y_train, y_pred_train)
# Out:
# 16.922475036479007

# %%
rf_r_squared = rf.score(x_test, y_test)
rf_r_squared
# Out:
# 0.9421024772312551

# %% [markdown]
# # KNN

# %%
#Using GridSearch CV to get the optimal prarameters.
from sklearn.model_selection import GridSearchCV
from sklearn import neighbors
from sklearn.neighbors import KNeighborsRegressor

# %%
param_grid = [{'weights':['uniform', 'Distance'],'n_neighbors':[10,20,30,40,50]}]
grid = GridSearchCV(neighbors.KNeighborsRegressor(), param_grid)
grid.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 25 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_regression.py", line 211, in fit
#     self.weights = _check_weights(self.weights)
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_base.py", line 83, in _check_weights
#     "weights not recognized: should be 'uniform', "
# ValueError: weights not recognized: should be 'uniform', 'distance', or a callable function
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py:972: UserWarning: One or more of the test scores are non-finite: [0.93598654        nan 0.93494317        nan 0.93386787        nan
#  0.93256008        nan 0.9312438         nan]
#   category=UserWarning,
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid=[{'n_neighbors': [10, 20, 30, 40, 50],
#                           'weights': ['uniform', 'Distance']}])

# %%
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.9359865357937679
# {'n_neighbors': 10, 'weights': 'uniform'}

# %%
knn = KNeighborsRegressor(weights = 'uniform', n_neighbors = 10)
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=10)

# %%
#Predicting with the model.
y_pred=knn.predict(x_test)

# %%
y_pred_train=knn.predict(x_train)

# %%
#Testing Error
rmse_knn = np.sqrt(mean_squared_error(y_test,y_pred))
rmse_knn
# Out:
# 4.0431976161730425

# %%
#R-Square value
knn_r_squared = r2_score(y_test, y_pred)
knn_r_squared

#Or knn_r_squared = knn.score(x_test, y_test)
# Out:
# 0.9436333466391067

# %% [markdown]
# # Gaussian Naive Bayes

# %%
from sklearn.gaussian_process.kernels import (RBF, Matern, RationalQuadratic,ExpSineSquared, DotProduct,ConstantKernel)
from sklearn.gaussian_process import GaussianProcessRegressor

# %%
# Determination of the kernel used and the value lenght_scale at which the optimization process starts
kernel = 1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-2, 1e3))

# %%
# Application of the regressor (alpha makes a statement about a possible noise of the training data)
gnb = GaussianProcessRegressor(kernel=kernel, alpha=0.1)
gnb.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/gaussian_process/kernels.py:437: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__constant_value is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/gaussian_process/kernels.py:427: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   ConvergenceWarning,
# GaussianProcessRegressor(alpha=0.1, kernel=1**2 * RBF(length_scale=1))

# %%
# Prediction of the dependent variable for the test dataset
y_pred, sigma = gnb.predict(x_test, return_std=True)

# %%
#Testing Errors
mean_squared_error(y_test, y_pred)
# Out:
# 15.699375422015803

# %%
rmse_gnb = np.sqrt(mean_squared_error(y_test,y_pred))
rmse_gnb
# Out:
# 3.962243735816337

# %%
gnb_r_squared = gnb.score(x_test, y_test)
gnb_r_squared
# Out:
# 0.9458679233292486

# %% [markdown]
# # Comparing Models

# %%
models_data=[["Multi Linear Regression",rmse_mlr,mlr_r_squared],
             ["Lasso Regression",rmse_lasso,Lasso_r_squared],
             ["Ridge Regression",rmse_ridge,Ridge_r_squared],
             ["Decision Tree Regressor",rmse_dtr,dtr_r_squared],
             ["Support Vector Regressor",rmse_svm,svm_r_squared],
             ["XGBoost",rmse_xgb,xgb_r_squared],
             ["Artificial Neural Network",rmse_ann,ann_r_squared],
             ["Random Forest Regressor",rmse_rf,rf_r_squared],
             ["K Nearest Neighbour",rmse_knn,knn_r_squared],
             ["ElasticNet Regression",rmse_elastic,ElasticNet_r_squared],
             ["Gaussian Naive bayes",rmse_gnb,gnb_r_squared]]

models_data=pd.DataFrame(models_data,columns=['Models','RMSE','R Squared'])

# %%
models_data.sort_values(by=['RMSE'], ascending=True)
# Out:
#                        Models      RMSE  R Squared
# 5                     XGBoost  3.450885   0.958939
# 10       Gaussian Naive bayes  3.962244   0.945868
# 8         K Nearest Neighbour  4.043198   0.943633
# 7     Random Forest Regressor  4.097735   0.942102
# 6   Artificial Neural Network  4.222718   0.938517
# 3     Decision Tree Regressor  4.326447   0.935459
# 0     Multi Linear Regression  4.373449   0.928875
# 1            Lasso Regression  4.559739   0.928688
# 2            Ridge Regression  4.560464   0.928696
# 9       ElasticNet Regression  4.562947   0.928619
# 4    Support Vector Regressor  8.887134   0.727670
